# %% [markdown]
# # Agent Architecture

# %% [markdown]
# ##### Reflection

# %%
from typing import Annotated, TypedDict

from langchain_core.messages import (
    AIMessage,
    BaseMessage,
    HumanMessage,
    SystemMessage,
)
from langchain_openai import ChatOpenAI
from langgraph.graph import END, START, StateGraph
from langgraph.graph.message import add_messages

# %%
# Initialize chat model
model = ChatOpenAI()


# Define state type
class State(TypedDict):
    messages: Annotated[list[BaseMessage], add_messages]


# Define prompts
generate_prompt = SystemMessage(
    "You are an essay assistant tasked with writing excellent 3-paragraph essays."
    " Generate the best essay possible for the user's request."
    " If the user provides critique, respond with a revised version of your previous attempts."
)

reflection_prompt = SystemMessage(
    "You are a teacher grading an essay submission. Generate critique and recommendations for the user's submission."
    " Provide detailed recommendations, including requests for length, depth, style, etc."
)

# %%
def generate(state: State) -> State:
    answer = model.invoke([generate_prompt] + state["messages"])
    return {"messages": [answer]}


def reflect(state: State) -> State:
    # Invert the messages to get the LLM to reflect on its own output
    cls_map = {AIMessage: HumanMessage, HumanMessage: AIMessage}
    # First message is the original user request. We hold it the same for all nodes
    translated = [reflection_prompt, state["messages"][0]] + [
        cls_map[msg.__class__](content=msg.content) for msg in state["messages"][1:]
    ]
    answer = model.invoke(translated)
    # We treat the output of this as human feedback for the generator
    return {"messages": [HumanMessage(content=answer.content)]}


def should_continue(state: State):
    if len(state["messages"]) > 6:
        # End after 3 iterations, each with 2 messages
        return END
    else:
        return "reflect"

# %%
# Build the graph
builder = StateGraph(State)
builder.add_node("generate", generate)
builder.add_node("reflect", reflect)
builder.add_edge(START, "generate")
builder.add_conditional_edges("generate", should_continue)
builder.add_edge("reflect", "generate")

graph = builder.compile()

# %%
# Example usage
initial_state = {
    "messages": [
        HumanMessage(
            content="오늘날 '어린 왕자'의 관련성에 대한 에세이를 작성해 보세요."
        )
    ]
}

# Run the graph
for output in graph.stream(initial_state):
    message_type = "generate" if "generate" in output else "reflect"
    print("\nNew message:", output[message_type]
          ["messages"][-1].content[:100], "...")
# Out:
# New message: '어린 왕자'라는 책은 세계적으로 사랑받는 문학 작품으로, 여전히 현재에도 그 안에 담긴 메시지와 가치가 우리에게 큰 영감을 주고 있습니다. 이 소설은 어른과 아이, 이성과 감성, ...
#
# New message: 이 에세이는 '어린 왕자'의 현대적인 관련성을 잘 소개하고 간략히 설명하고 있습니다. 그러나 조금 더 심도 있는 분석과 구체적인 예시를 통해 의견을 뒷받침할 수 있도록 노력해야 합 ...
#
# New message: '어린 왕자'는 현대 사회에서 여전히 깊은 감정과 생각을 일으키는 문학적 걸작으로 손꼽힙니다. 이 작품은 무엇보다도 소소한 순간과 순수한 감수성에 대한 사색을 통해 현대 사회의 고 ...
#
# New message: 이번에 작성한 에세이는 '어린 왕자'의 현대적인 의미와 가치를 잘 포착하고 있습니다. 그러나 더 깊이 있는 분석과 다양한 예시를 통해 주장을 보다 강화하고 전달력을 높일 수 있도록 ...
#
# New message: '어린 왕자'는 현대 사회에도 여전히 많은 의미와 가치를 담고 있는 문학 작품입니다. 이 작품은 어린 왕자와 여우, 그리고 장미와 별들의 대화를 통해 인간의 본질과 삶의 의미를 탐 ...
#
# New message: 이번에 작성한 에세이는 '어린 왕자'의 현대적인 가치와 의미를 잘 강조하고 있습니다. 그러나 좀 더 다양한 측면을 포함하고 깊이 있는 분석을 통해 주제를 보다 포괄적으로 다룰 수  ...
#
# New message: '어린 왕자'는 현대 사회에서도 여전히 빛을 발하는 문학적 명작으로, 그 안에 담긴 다양한 주제와 메시지들이 오늘날의 우리에게도 큰 울림을 전달하고 있습니다. 이 작품은 자아성찰과 ...

# %% [markdown]
# ##### Subgraph Direct

# %%
from typing import TypedDict
from langgraph.graph import START, StateGraph


# Define the state types for parent and subgraph
class State(TypedDict):
    foo: str  # this key is shared with the subgraph


class SubgraphState(TypedDict):
    foo: str  # this key is shared with the parent graph
    bar: str

# %%
# Define subgraph
def subgraph_node(state: SubgraphState):
    # note that this subgraph node can communicate with the parent graph via the shared "foo" key
    return {"foo": state["foo"] + "bar"}


subgraph_builder = StateGraph(SubgraphState)
subgraph_builder.add_node("subgraph_node", subgraph_node)
# Additional subgraph setup would go here
# subgraph_builder.add_edge(START, "subgraph_node")
subgraph = subgraph_builder.compile()

# Define parent graph
builder = StateGraph(State)
builder.add_node("subgraph", subgraph)
builder.add_edge(START, "subgraph")
# Additional parent graph setup would go here
graph = builder.compile()

# %%
# Example usage
initial_state = {"foo": "hello"}
result = graph.invoke(initial_state)
print(f"Result: {result}")  # Should append "bar" to the foo value
# Out:
# Result: {'foo': 'hellobar'}

# %% [markdown]
# ##### Subgraph Function

# %%
from typing import TypedDict
from langgraph.graph import START, StateGraph


class State(TypedDict):
    foo: str


class SubgraphState(TypedDict):
    # none of these keys are shared with the parent graph state
    bar: str
    baz: str

# %%
# Define subgraph
def subgraph_node(state: SubgraphState):
    return {"bar": state["bar"] + "baz"}


subgraph_builder = StateGraph(SubgraphState)
subgraph_builder.add_node("subgraph_node", subgraph_node)
subgraph_builder.add_edge(START, "subgraph_node")
# Additional subgraph setup would go here
subgraph = subgraph_builder.compile()


# Define parent graph node that invokes subgraph
def node(state: State):
    # transform the state to the subgraph state
    response = subgraph.invoke({"bar": state["foo"]})
    # transform response back to the parent state
    return {"foo": response["bar"]}


builder = StateGraph(State)
# note that we are using `node` function instead of a compiled subgraph
builder.add_node("node", node)
builder.add_edge(START, "node")
# Additional parent graph setup would go here
graph = builder.compile()

# %%
# Example usage
initial_state = {"foo": "hello"}
result = graph.invoke(initial_state)
print(
    f"Result: {result}"
)  # Should transform foo->bar, append "baz", then transform bar->foo
# Out:
# Result: {'foo': 'hellobaz'}

# %% [markdown]
# ##### Supervisor

# %%
from typing import Literal
from pydantic import BaseModel
from langchain_openai import ChatOpenAI
from langgraph.graph import StateGraph, MessagesState, START
from langchain_core.messages import AIMessage, HumanMessage

# ──────────────────────────────
# 1) 모델 준비
# ──────────────────────────────
class SupervisorDecision(BaseModel):
    next: Literal["researcher", "coder", "FINISH"]

decision_llm = ChatOpenAI(model="gpt-4o-mini", temperature=0) \
               .with_structured_output(SupervisorDecision)   # supervisor 전용
agent_llm    = ChatOpenAI(model="gpt-4o-mini", temperature=0) # 일반 대화용

# ──────────────────────────────
# 2) 프롬프트와 노드 정의
# ──────────────────────────────
agents = ["researcher", "coder"]
sys1 = f"""You are a supervisor managing: {agents}.
Choose *one* worker to act next. When everything is done, answer FINISH."""
sys2 = f"Who should act next? Choose from {', '.join(agents)}, FINISH."

class AgentState(MessagesState):
    next: Literal["researcher", "coder", "FINISH"]

def supervisor(state: AgentState):
    messages = [("system", sys1), *state["messages"], ("system", sys2)]
    decision: SupervisorDecision = decision_llm.invoke(messages)
    # supervisor가 말도 남기고 싶다면 메시지로 감싼다
    
    # 콘솔에 supervisor의 판단을 출력
    print("\n📋 [Supervisor Decision]")
    print(f"- Available agents: {', '.join(agents)}")
    print(f"- User request: {state['messages'][-1].content}")
    print(f"- 💡 Decision: {decision.next}")
    
    return {
        "next": decision.next,
        "messages": [AIMessage(content=f"[Supervisor] next → {decision.next}")]
    }

def researcher(state: AgentState):
    prompt = [
        ("system", "You are a research assistant."),
        ("user",   state["messages"][-1].content),
    ]
    reply = agent_llm.invoke(prompt)
    return {"messages": [reply]}   # reply는 AIMessage

def coder(state: AgentState):
    prompt = [
        ("system", "You are a coding assistant."),
        ("user",   state["messages"][-1].content),
    ]
    reply = agent_llm.invoke(prompt)
    return {"messages": [reply]}

# ──────────────────────────────
# 3) 그래프 빌드
# ──────────────────────────────
builder = StateGraph(AgentState)
builder.add_node("supervisor", supervisor)
builder.add_node("researcher", researcher)
builder.add_node("coder", coder)

builder.add_edge(START, "supervisor")
builder.add_conditional_edges("supervisor", lambda s: s["next"])
builder.add_edge("researcher", "supervisor")
builder.add_edge("coder",      "supervisor")
graph = builder.compile()

# ──────────────────────────────
# 4) 실행
# ──────────────────────────────
initial_state = {
    "messages": [HumanMessage(content="I need help analysing data and creating a visualization.")],
    "next": "supervisor"
}

for step in graph.stream(initial_state):
    print(f"\n[STEP] next = {step.get('next')}")
    if step.get("messages"):
        print(step["messages"][-1].content)
# Out:
# 📋 [Supervisor Decision]
# - Available agents: researcher, coder
# - User request: I need help analysing data and creating a visualization.
# - 💡 Decision: researcher
#
# [STEP] next = None
#
# [STEP] next = None
#
# 📋 [Supervisor Decision]
# - Available agents: researcher, coder
# - User request: It seems like you're looking for a way to transition from a supervisor role to a researcher role. Here are some steps you might consider:
#
# 1. **Identify Your Research Interests**: Determine what areas of research excite you the most. This could be related to your current field or a new area you want to explore.
#
# 2. **Enhance Your Skills**: Depending on your research interests, you may need to acquire new skills or knowledge. This could involve taking courses, attending workshops, or self-study.
#
# 3. **Network with Researchers**: Connect with researchers in your field of interest. Attend conferences, seminars, and workshops to meet professionals and learn about current research trends.
#
# 4. **Seek Research Opportunities**: Look for opportunities to collaborate on research projects, either within your current organization or externally. This could involve volunteering for research tasks or applying for research assistant positions.
#
# 5. **Publish Your Work**: If you have the opportunity, try to publish your findings in academic journals or present at conferences. This will help establish your credibility as a researcher.
#
# 6. **Consider Further Education**: Depending on your goals, you might consider pursuing a higher degree (like a Master's or PhD) that focuses on research methodologies and practices.
#
# 7. **Transition Gradually**: If possible, start by incorporating research into your current role. This could involve leading a research project or integrating research activities into your supervisory responsibilities.
#
# 8. **Stay Informed**: Keep up with the latest research in your field by reading journals, attending lectures, and engaging with the academic community.
#
# By following these steps, you can effectively transition from a supervisory role to a research-focused career.
# - 💡 Decision: coder
#
# [STEP] next = None
#
# [STEP] next = None
#
# 📋 [Supervisor Decision]
# - Available agents: researcher, coder
# - User request: It seems like you're looking to transition from a supervisor role to a coding role. Here are some steps you can take to make that transition successfully:
#
# 1. **Assess Your Current Skills**: Identify the skills you already have that are transferable to coding, such as problem-solving, project management, and communication.
#
# 2. **Choose a Programming Language**: Start with a language that is beginner-friendly and widely used, such as Python or JavaScript.
#
# 3. **Online Courses and Resources**: Enroll in online courses on platforms like Coursera, Udemy, or freeCodeCamp. These platforms offer structured learning paths for beginners.
#
# 4. **Practice Coding**: Use platforms like LeetCode, HackerRank, or Codecademy to practice coding problems and build your skills.
#
# 5. **Build Projects**: Start small by building simple projects. This could be anything from a personal website to a small application. Projects help solidify your learning and give you something to showcase.
#
# 6. **Join Coding Communities**: Engage with communities on platforms like GitHub, Stack Overflow, or Reddit. This can provide support, resources, and networking opportunities.
#
# 7. **Contribute to Open Source**: Once you feel comfortable, consider contributing to open-source projects. This is a great way to gain experience and collaborate with other developers.
#
# 8. **Update Your Resume**: As you gain skills and complete projects, update your resume to reflect your new coding abilities and any relevant experience.
#
# 9. **Apply for Entry-Level Positions**: Look for internships or junior developer positions that can help you get your foot in the door.
#
# 10. **Keep Learning**: Technology is always evolving, so continue to learn and adapt to new tools and languages.
#
# If you have specific questions or need guidance on any of these steps, feel free to ask!
# - 💡 Decision: coder
#
# [STEP] next = None
#
# [STEP] next = None
#
# 📋 [Supervisor Decision]
# - Available agents: researcher, coder
# - User request: It seems like you're looking to transition from a supervisor role to a coding or programming role. Here are some steps you can take to make that transition:
#
# 1. **Assess Your Current Skills**: Identify any technical skills you already have that may be relevant to coding. This could include familiarity with software tools, project management, or any programming experience.
#
# 2. **Choose a Programming Language**: Start with a language that is beginner-friendly and widely used, such as Python or JavaScript. These languages have extensive resources and communities that can help you learn.
#
# 3. **Online Courses and Tutorials**: Enroll in online courses on platforms like Coursera, Udemy, or Codecademy. Many of these platforms offer structured learning paths for beginners.
#
# 4. **Practice Coding**: Use platforms like LeetCode, HackerRank, or Codewars to practice coding problems. This will help you improve your problem-solving skills and coding proficiency.
#
# 5. **Build Projects**: Start working on small projects that interest you. This could be anything from a personal website to a simple application. Building projects will help you apply what you've learned and create a portfolio.
#
# 6. **Join Coding Communities**: Engage with online communities such as Stack Overflow, GitHub, or local coding meetups. Networking with other coders can provide support and opportunities for collaboration.
#
# 7. **Contribute to Open Source**: Once you feel comfortable with your skills, consider contributing to open-source projects. This is a great way to gain experience and showcase your work.
#
# 8. **Update Your Resume**: As you gain skills and experience, update your resume to reflect your new coding abilities and any projects you've completed.
#
# 9. **Apply for Entry-Level Positions**: Look for entry-level coding positions or internships that will allow you to gain professional experience in the field.
#
# 10. **Keep Learning**: Technology is always evolving, so continue to learn new languages, frameworks, and tools to stay current in the industry.
#
# If you have specific questions or need guidance on any of these steps, feel free to ask!
# - 💡 Decision: coder
#
# [STEP] next = None
#
# [STEP] next = None
#
# 📋 [Supervisor Decision]
# - Available agents: researcher, coder
# - User request: It seems like you're looking to transition from a supervisor role to a coding role. Here are some steps you can take to make that transition successfully:
#
# 1. **Assess Your Current Skills**: Identify the programming languages and technologies you are already familiar with. This will help you understand where you stand and what you need to learn.
#
# 2. **Learn Programming Languages**: If you haven't already, start learning programming languages that are in demand. Popular choices include Python, JavaScript, Java, C#, and Ruby. Online platforms like Codecademy, freeCodeCamp, and Coursera can be helpful.
#
# 3. **Build Projects**: Apply what you learn by building small projects. This could be anything from a personal website to a simple application. Projects will help you solidify your knowledge and provide you with a portfolio to showcase your skills.
#
# 4. **Contribute to Open Source**: Participating in open-source projects can provide real-world experience and help you learn from other developers. Websites like GitHub have many projects looking for contributors.
#
# 5. **Networking**: Connect with other developers through meetups, online forums, or social media platforms like LinkedIn. Networking can lead to job opportunities and mentorship.
#
# 6. **Consider Formal Education**: Depending on your background, you might consider taking formal courses or bootcamps that focus on coding. These can provide structured learning and often include job placement assistance.
#
# 7. **Prepare for Interviews**: Once you feel confident in your coding skills, start preparing for technical interviews. Practice coding challenges on platforms like LeetCode, HackerRank, or CodeSignal.
#
# 8. **Update Your Resume**: Tailor your resume to highlight your coding skills and any relevant projects or experiences. Emphasize your problem-solving abilities and any leadership experience from your supervisory role.
#
# 9. **Apply for Jobs**: Start applying for entry-level coding positions or internships. Be open to roles that may not be your ideal job but can help you gain experience.
#
# 10. **Keep Learning**: The tech field is always evolving, so continue to learn new technologies and improve your skills even after you land a coding job.
#
# If you have specific questions or need guidance on any of these steps, feel free to ask!
# - 💡 Decision: coder
#
# [STEP] next = None
#
# [STEP] next = None
#
# 📋 [Supervisor Decision]
# - Available agents: researcher, coder
# - User request: It seems like you're looking to transition from a supervisor role to a coder role. Here are some steps you can take to make that transition effectively:
#
# 1. **Assess Your Current Skills**: Identify any programming skills you already have. This could include familiarity with coding languages, software development processes, or project management.
#
# 2. **Choose a Programming Language**: Start with a language that is beginner-friendly and widely used, such as Python, JavaScript, or Ruby. Each has its own strengths depending on what you want to do (web development, data analysis, etc.).
#
# 3. **Online Courses and Resources**: Enroll in online courses on platforms like Coursera, Udemy, or freeCodeCamp. These platforms offer structured learning paths for beginners.
#
# 4. **Practice Coding**: Use platforms like LeetCode, HackerRank, or Codecademy to practice coding problems. Building small projects can also help solidify your understanding.
#
# 5. **Build a Portfolio**: Start working on personal projects or contribute to open-source projects. This will help you gain practical experience and create a portfolio to showcase your skills.
#
# 6. **Networking**: Connect with other coders and developers through forums, social media, or local meetups. Networking can provide support and open up job opportunities.
#
# 7. **Stay Updated**: The tech field is always evolving. Follow industry news, blogs, and podcasts to stay informed about new technologies and best practices.
#
# 8. **Consider Formal Education**: If you're serious about a career in coding, you might consider enrolling in a coding bootcamp or pursuing a degree in computer science.
#
# 9. **Apply for Entry-Level Positions**: Once you feel confident in your skills, start applying for entry-level coding positions or internships to gain professional experience.
#
# 10. **Seek Feedback and Iterate**: As you learn and grow, seek feedback on your code from more experienced developers. Use this feedback to improve your skills continuously.
#
# If you have specific questions or need guidance on a particular aspect of coding, feel free to ask!
# - 💡 Decision: coder
#
# [STEP] next = None
#
# [STEP] next = None
#
# 📋 [Supervisor Decision]
# - Available agents: researcher, coder
# - User request: It seems like you're looking to transition from a supervisor role to a coding role. Here are some steps you can take to make that transition successfully:
#
# 1. **Assess Your Current Skills**: Identify any programming skills you already have. This could include familiarity with coding languages, software development processes, or project management.
#
# 2. **Choose a Programming Language**: Start with a language that is beginner-friendly and widely used, such as Python, JavaScript, or Ruby. Each has its own strengths depending on the area you want to focus on (web development, data analysis, etc.).
#
# 3. **Online Courses and Resources**: Utilize online platforms like Codecademy, freeCodeCamp, Coursera, or Udemy to take structured courses. Many of these platforms offer free resources as well.
#
# 4. **Practice Coding**: Use platforms like LeetCode, HackerRank, or Codewars to practice coding problems. This will help you improve your problem-solving skills and coding proficiency.
#
# 5. **Build Projects**: Start small by building personal projects. This could be anything from a simple website to a small application. Projects will help you apply what you’ve learned and build a portfolio.
#
# 6. **Join a Community**: Engage with coding communities on platforms like GitHub, Stack Overflow, or Reddit. This will help you learn from others, get feedback, and stay motivated.
#
# 7. **Contribute to Open Source**: Once you feel comfortable, consider contributing to open-source projects. This is a great way to gain experience, collaborate with others, and enhance your resume.
#
# 8. **Networking**: Connect with other coders and professionals in the field. Attend meetups, webinars, or tech conferences to expand your network.
#
# 9. **Prepare for Job Applications**: Update your resume to highlight your new skills and projects. Tailor your applications to showcase your coding abilities and any relevant experience from your supervisory role.
#
# 10. **Stay Persistent**: Transitioning careers can be challenging, so stay persistent and keep learning. The tech field is always evolving, and continuous learning is key.
#
# If you have specific questions or need guidance on a particular aspect of coding, feel free to ask!
# - 💡 Decision: FINISH
#
# [STEP] next = None
